# %%
import numpy as np 
import requests
from ast import literal_eval

def get_data():
    data = {}

    urls = [
        {
            'name': 'pasajeros-2016',
            'key': '3d95a925-784c-5f63-8ad4-5d27db0a9d7c'
        },
        {
            'name': 'pasajeros-2017',
            'key': 'ab6f0e77-2b94-5b04-b4d7-0856c3d9ed9f'
        },
        {
            'name': 'viajes-2016',
            'key': 'f9e37e37-b055-5773-8e76-7212517e0f81'
        },
        {
            'name': 'viajes-2017',
            'key': 'bdd2a630-130a-5059-bb27-d0fcb8f927c7'
        }, 
        {
            'name': 'lineas-aereas',
            'key': '1fbd58f2-92a5-53b8-b8db-b87eebef0e3a'
        }
    ]

    for url in urls:
        response = requests.get('https://analytics.deacero.com/api/expuesta/sqlexp/' + url['key'])
        json_response = response.json()

        data.setdefault(url['name'], literal_eval(json_response))

    set_data(data)

def set_data(data):
    pasajeros = {
        'pasajeros-2016': data['pasajeros-2016'],
        'pasajeros-2017': data['pasajeros-2017']
    }


    viajes = {
        'viajes-2016': data['viajes-2016'],
        'viajes-2017': data['viajes-2017']
    }

    lineas_aereas = data['lineas-aereas']

    joined_pasajeros = pasajeros['pasajeros-2016'] + pasajeros['pasajeros-2017']
    joined_viajes = viajes['viajes-2016'] + viajes['viajes-2017']

    get_pasajeros_view(joined_pasajeros, joined_viajes, lineas_aereas)

def get_viajes(id_pasajero, viajes):
    viajes_pasajero = []
    
    for v in viajes:
       if v['Cve_Cliente'] == id_pasajero:
        viajes_pasajero.append(v)

    return viajes_pasajero


def get_pasajeros_view(pasajeros, viajes, lineas_aereas):
    views = []

    for pasajero in pasajeros:
        viajes_pasajero = get_viajes(pasajero['ID_Pasajero'], viajes)

        views.append({
            "pasajero": pasajero,
            "viajes": viajes_pasajero
        })

    get_aereolineas_view(views, lineas_aereas)

def get_viajes_aereolinea(aereolinea_code, aereolinea_name, views):
    viajes_aereolinea = []

    for v in views:
        for viaje in v['viajes']:
            if viaje['Cve_LA'] == aereolinea_code:
                viajes_aereolinea.append({
                    "ruta": viaje['Ruta'],
                    "precio": viaje['Precio'],
                    "clase": viaje['Clase'],
                    "fecha de viaje": viaje['Viaje'],
                    "edad": v['pasajero']['Edad'],
                    "linea aerea": aereolinea_name
                })

    return viajes_aereolinea

def get_aereolineas_view(views, lineas_aereas):
    results = []

    for aereolinea in lineas_aereas:
        r = get_viajes_aereolinea(aereolinea['Code'], aereolinea['Linea_Aerea'], views)
        results.append(r)

    print(results)

get_data()
# Out:
# [[{'ruta': 'DAL-AMA', 'precio': 186, 'clase': '9\\/6\\/2016', 'fecha de viaje': '9\\/6\\/2016', 'edad': 60, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-OKC', 'precio': 205, 'clase': '2\\/22\\/2016', 'fecha de viaje': '2\\/22\\/2016', 'edad': 40, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-LGA', 'precio': 215, 'clase': '5\\/8\\/2016', 'fecha de viaje': '5\\/8\\/2016', 'edad': 40, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-PHX', 'precio': 261, 'clase': '3\\/5\\/2016', 'fecha de viaje': '3\\/5\\/2016', 'edad': 55, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-GRR', 'precio': 221, 'clase': '6\\/13\\/2016', 'fecha de viaje': '6\\/13\\/2016', 'edad': 21, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-AMA', 'precio': 63, 'clase': '2\\/11\\/2016', 'fecha de viaje': '2\\/11\\/2016', 'edad': 53, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-OKC', 'precio': 223, 'clase': '11\\/24\\/2016', 'fecha de viaje': '11\\/24\\/2016', 'edad': 22, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-OKC', 'precio': 269, 'clase': '6\\/12\\/2016', 'fecha de viaje': '6\\/12\\/2016', 'edad': 43, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-HOU', 'precio': 71, 'clase': '5\\/21\\/2016', 'fecha de viaje': '5\\/21\\/2016', 'edad': 48, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-AMA', 'precio': 133, 'clase': '3\\/18\\/2016', 'fecha de viaje': '3\\/18\\/2016', 'edad': 48, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-AUS', 'precio': 133, 'clase': '2\\/21\\/2016', 'fecha de viaje': '2\\/21\\/2016', 'edad': 42, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-SLC', 'precio': 150, 'clase': '6\\/11\\/2016', 'fecha de viaje': '6\\/11\\/2016', 'edad': 25, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-GRR', 'precio': 68, 'clase': '3\\/12\\/2016', 'fecha de viaje': '3\\/12\\/2016', 'edad': 25, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-ELP', 'precio': 195, 'clase': '5\\/6\\/2016', 'fecha de viaje': '5\\/6\\/2016', 'edad': 35, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-ATL', 'precio': 135, 'clase': '9\\/20\\/2016', 'fecha de viaje': '9\\/20\\/2016', 'edad': 50, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-PHX', 'precio': 132, 'clase': '7\\/29\\/2016', 'fecha de viaje': '7\\/29\\/2016', 'edad': 52, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-AUS', 'precio': 216, 'clase': '6\\/23\\/2016', 'fecha de viaje': '6\\/23\\/2016', 'edad': 34, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-MDW', 'precio': 74, 'clase': '11\\/18\\/2016', 'fecha de viaje': '11\\/18\\/2016', 'edad': 39, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-GRR', 'precio': 180, 'clase': '10\\/5\\/2016', 'fecha de viaje': '10\\/5\\/2016', 'edad': 35, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-LGA', 'precio': 216, 'clase': '11\\/11\\/2016', 'fecha de viaje': '11\\/11\\/2016', 'edad': 42, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-AUS', 'precio': 55, 'clase': '10\\/26\\/2016', 'fecha de viaje': '10\\/26\\/2016', 'edad': 26, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-OKC', 'precio': 114, 'clase': '2\\/24\\/2016', 'fecha de viaje': '2\\/24\\/2016', 'edad': 26, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-SLC', 'precio': 56, 'clase': '7\\/6\\/2016', 'fecha de viaje': '7\\/6\\/2016', 'edad': 26, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-AMA', 'precio': 58, 'clase': '2\\/18\\/2016', 'fecha de viaje': '2\\/18\\/2016', 'edad': 64, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-MDW', 'precio': 165, 'clase': '2\\/28\\/2016', 'fecha de viaje': '2\\/28\\/2016', 'edad': 40, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-ELP', 'precio': 114, 'clase': '7\\/3\\/2016', 'fecha de viaje': '7\\/3\\/2016', 'edad': 68, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-LGA', 'precio': 140, 'clase': '4\\/18\\/2016', 'fecha de viaje': '4\\/18\\/2016', 'edad': 49, 'linea aerea': 'American Airlines'}, {'ruta': 'DAL-OKC', 'precio': 181, 'clase': '2\\/5\\/2016', 'fecha de viaje': '2\\/5\\/2016',  ...
